# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
from catch import CatchEnv

# %%
env = CatchEnv()
number_of_episodes = 1

# %%
init_state = env.reset()

# %%
init_state.shape
# Out:
# (84, 84, 4)

# %%
for image_index in range(4):
    plt.figure()
    plt.title(f"image - {image_index}")
    plt.imshow(init_state[:, :, image_index])

# %%
action = random.randint(0, 2)
print(f"action: {action}")
# Out:
# action: 1

# %%
next_state, reward, terminal = env.step(action)

# %%
action = random.randint(0, 2)
print(f"action: {action}")
# Out:
# action: 1

# %%
next_state, reward, terminal = env.step(action)

# %%
action = random.randint(0, 2)
print(f"action: {action}")
# Out:
# action: 1

# %%
next_state, reward, terminal = env.step(action)

# %%
for image_index in range(4):
    plt.figure()
    plt.title(f"image - {image_index}")
    plt.imshow(next_state[:, :, image_index])

# %%
np.min(next_state), np.max(next_state)
# Out:
# (0.0, 0.875)
